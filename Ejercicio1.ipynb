# %%
import pandas as pd

# %%
data = pd.read_json("data/aeropuertos_5000_es.json")

# %%
data.shape
# Out:
# (5000, 21)

# %%
data.describe()
# Out:
#        id_aeropuerto      latitud     longitud  altitud_pies  numero_pistas  \
# count    5000.000000  5000.000000  5000.000000   5000.000000    5000.000000
# mean     2500.500000     8.215304    -0.248751   6580.439800       2.003200
# std      1443.520003    36.423397    98.448161   3723.439911       1.125097
# min         1.000000   -54.993560  -169.964060      8.000000       1.000000
# 25%      1250.750000   -23.212916   -84.203788   3378.250000       1.000000
# 50%      2500.500000     8.401972    -1.271831   6640.000000       2.000000
# 75%      3750.250000    39.961261    84.822560   9829.250000       2.000000
# max      5000.000000    69.996905   169.992051  12994.000000       6.000000
#
#        pista_mas_larga_pies  diferencia_utc  trafico_pasajeros_anual  \
# count           5000.000000     5000.000000             5.000000e+03
# mean            6797.930800       -0.180300             7.176688e+06
# std             3196.401741        4.918992             1.834472e+07
# ...
